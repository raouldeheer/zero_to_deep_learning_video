# %% [markdown]
# # uitwerking opdracht 3

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam, SGD

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../../data/insurance.csv')
x= df[['age']].values
y= df[['charges']].values

# %%
df.head()
df.plot(kind='scatter', x = 'age', y = 'charges',
      title='Age to cost')
# Out:
# <AxesSubplot:title={'center':'Age to cost'}, xlabel='age', ylabel='charges'>

# %%
model = Sequential()
model.add(Dense(1, input_shape=(1,)))
model.summary()
model.compile(Adam(learning_rate=0.8), 'mean_squared_error')
model.fit(x, y, epochs=20)
# Out:
# Model: "sequential_13"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_13 (Dense)             (None, 1)                 2
# =================================================================
# Total params: 2
# Trainable params: 2
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 42/42 [==============================] - 0s 952us/step - loss: 304713664.0000
# Epoch 2/20
# 42/42 [==============================] - 0s 829us/step - loss: 271042784.0000
# Epoch 3/20
# 42/42 [==============================] - 0s 879us/step - loss: 242670864.0000
# Epoch 4/20
# 42/42 [==============================] - 0s 920us/step - loss: 219166656.0000
# Epoch 5/20
# 42/42 [==============================] - 0s 927us/step - loss: 199722080.0000
# Epoch 6/20
# 42/42 [==============================] - 0s 854us/step - loss: 184232576.0000
# Epoch 7/20
# 42/42 [==============================] - 0s 976us/step - loss: 171588976.0000
# Epoch 8/20
# 42/42 [==============================] - 0s 854us/step - loss: 161913376.0000
# Epoch 9/20
# 42/42 [==============================] - 0s 903us/step - loss: 154302032.0000
# Epoch 10/20
# 42/42 [==============================] - 0s 878us/step - loss: 148637536.0000
# Epoch 11/20
# 42/42 [==============================] - 0s 903us/step - loss: 144289472.0000
# Epoch 12/20
# 42/42 [==============================] - 0s 854us/step - loss: 141262864.0000
# Epoch 13/20
# 42/42 [==============================] - 0s 927us/step - loss: 138977168.0000
# Epoch 14/20
# 42/42 [==============================] - 0s 902us/step - loss: 137422960.0000
# Epoch 15/20
# 42/42 [==============================] - 0s 903us/step - loss: 136368832.0000
# Epoch 16/20
# 42/42 [==============================] - 0s 829us/step - loss: 135663024.0000
# Epoch 17/20
# 42/42 [==============================] - 0s 903us/step - loss: 135178208.0000
# Epoch 18/20
# 42/42 [==============================] - 0s 927us/step - loss: 134864592.0000
# Epoch 19/20
# 42/42 [==============================] - 0s 805us/step - loss: 134666656.0000
# Epoch 20/20
# 42/42 [==============================] - 0s 1ms/step - loss: 134549776.0000

# %%
y_pred  = model.predict(x)
y
df.plot(kind='scatter', x = 'age', y = 'charges',
      title='Cost to age')
plt.plot(x, y_pred, color='red')
